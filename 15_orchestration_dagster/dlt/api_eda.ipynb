# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"

def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


query = 'data engineer'
example_search_loop_through_hits(query)
# Out:
# Data Engineer, Lunds kommun
# Data Engineer, SANDVIK AB
# Data Engineer, Telescope Services AB
# Data Engineer, owision AB
# Data Engineer, Gears Of Leo AB
# Data Engineer, Telenor Sverige AB
# Data Engineer, Stockholm Exergi AB
# Data Engineer, NXT Interim Stockholm AB
# Data Engineer, AB Trav och Galopp
# Data Engineer, Qliro AB
# Data Engineer, Coody IO AB
# Data Engineer, Majority Sweden AB
# Data Engineer, AFRY AB
# Data Engineer, Intenso Teknikrekrytering AB
# Data Engineer, Synteda AB
# Data Engineer, Redeploy AB
# Data Engineer, Kambi Sweden AB
# Data Engineer, Epidemic Sound AB
# Data Engineer, Knowit AB (Publ)
# Data Engineer, Zcelero AB
# Data Engineer, Webstep AB
# Senior Data Engineer, Professional Galaxy AB
# AI Data Engineer, Etteplan Sweden AB
# Senior Data Engineer, Scania CV AB
# Senior Data Engineer, SwedQ AB
# Senior Data Engineer, 2Mnordic IT Consulting AB
# Senior Data Engineer, 2Mnordic IT Consulting AB
# Senior Data Engineer, Sinch Sweden AB
# Senior Data Engineer, Redeploy AB
# Senior Data Engineer, Software by QUOKKA AB
# Erfaren Data Engineer, Knowit AB (Publ)
# Senior Data Engineer, Qinshift AB
# Senior Data Engineer, Castra Group AB
# Data Engineer – 10027, Veritaz AB
# Data engineer - AWS, Sogeti Sverige AB
# Data Engineer – 9933, Veritaz AB
# Data engineer - Azure, Sogeti Sverige AB
# Data Engineer till Matas Group, Ants Akademiskt Nätverk av Tekniska Studenter AB
# Senior data engineer till Capio, Capio Sverige AB
# Data Engineer - Generative AI, Axis Communications AB
# Data Engineer till Sogeti Stockholm, Sogeti Sverige AB
# Data Engineer till Sogeti Göteborg, Sogeti Sverige AB
# Data Engineer till Sogeti Jönköping, Sogeti Sverige AB
# Lead Data Engineer, Digital Engineering, Polarium Energy Solutions AB
# Data Engineer - Platform Infrastructure, Platform 24 Healthcare AB
# Data Engineer till Finity People, Nordic recruitment Group AB
# Data Engineer in the Sustainability Data and Analytics Hub, Volvo Personvagnar AB
# Senior Data Engineer – Stockholm heltid, Modernera AB
# Data Engineer – Automotive Innovation Lab, Academic Work Sweden AB
# Välkänt IoT bolag söker Data Engineer, Academic Work Sweden AB
# Data Engineer till Combitech i Stockholm, Combitech AB
# Data Engineer till BITVIS i Linköping, Tech Talents Consulting i Sverige AB
# Data Engineer med fokus på SAS, Knowit AB (Publ)
# Combitech söker en Data Engineer i Malmö med flera, Combitech AB
# Data Engineer / Machine Learning / AI / Cloud, Meet a Group international AB
# Data Engineer / Machine Learning / AI / Cloud, Combine Control Systems AB
# Analytics Architect/Data Engineer, Dometic Holding AB
# Dataanalys, simulering och optimering inom flex-tjänster i elsystemet, Checkwatt AB
# Vill du arbeta med att utveckla vår datadrivna analys?, Finansinspektionen
# Business Intelligence-utvecklare till Örebro, Sogeti Sverige AB
# Data Post-Processing Development Engineer, Infotiv Information & Design AB
# Senior Data Fabric Engineer, Sinch Sweden AB
# Data Governance Engineer, Stockholm/Copenhagen, PostNord Group AB
# Software Engineer & Data Scientist, Hopsworks AB
# Site Engineer, Data Center & Critical Facilities, Coromatic AB
# Site Engineer / Drifttekniker Data Center & Critical Facilities, Coromatic AB

# %%
example_search_return_number_of_hits(query)
# Out:
# Number of hits = 145

# %%
response_json = _get_ads({'q': query, 'limit': 100})
response_json
# Out:
# {'total': {'value': 145},
#  'positions': 295,
#  'query_time_in_millis': 9,
#  'result_time_in_millis': 309,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['lärare'],
#   'location': ['stockholm'],
#   'skill_must': [],
#   'occupation_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '28976561',
#    'external_id': '46-556656-5502-8883',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976561',
#    'logo_url': None,
#    'headline': 'Lärare i Matematik och Svenska på ESS-gymnasiet',
#    'application_deadline': '2024-08-02T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-i-matematik-och-svenska-pa-ess-gymnasiet. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-i-matematik-och-svenska-pa-ess-gymnasiet. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/larare-i-matematik-och-svenska-pa-ess-gymnasiet',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:39',
#    'last_publication_date': '2024-08-02T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392959576},
#   {'relevance': 1.0,
#    'id': '28976583',
#    'external_id': '46-556656-5502-8874',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976583',
#    'logo_url': None,
#    'headline': 'Lärare Trä- och metallslöjd åk 3-9',
#    'application_deadline': '2024-08-04T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-tra-och-metallslojd-ak-3-9. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-tra-och-metallslojd-ak-3-9. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/larare-tra-och-metallslojd-ak-3-9',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'chKA_ZiB_9xd',
#     'label': 'Träslöjdare',
#     'legacy_ams_taxonomy_id': '3222'},
#    'occupation_group': {'concept_id': 'aKdV_u7V_R5j',
#     'label': 'Musikinstrumentmakare och övriga konsthantverkare',
#     'legacy_ams_taxonomy_id': '7319'},
#    'occupation_field': {'concept_id': 'PaxQ_o1G_wWH',
#     'label': 'Hantverk',
#     'legacy_ams_taxonomy_id': '6'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'chKA_ZiB_9xd',
#       'label': 'Träslöjdare',
#       'legacy_ams_taxonomy_id': '3222'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:38',
#    'last_publication_date': '2024-08-04T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392958475},
#   {'relevance': 1.0,
#    'id': '28976584',
#    'external_id': '46-556656-5502-8876',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976584',
#    'logo_url': None,
#    'headline': 'Legitimerad lärare i Hkk och gärna annat ämne',
#    'application_deadline': '2024-07-23T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/legitimerad-larare-i-hkk-och-garna-annat-amne-1. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/legitimerad-larare-i-hkk-och-garna-annat-amne-1. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/legitimerad-larare-i-hkk-och-garna-annat-amne-1',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:38',
#    'last_publication_date': '2024-07-23T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392958849},
#   {'relevance': 1.0,
#    'id': '28976558',
#    'external_id': '46-556656-5502-8870',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976558',
#    'logo_url': None,
#    'headline': 'Legitimerad och behörig lärare utbildningsförvaltningen',
#    'application_deadline': '2024-07-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/legitimerad-och-behorig-larare-utbildningsforvaltningen. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/legitimerad-och-behorig-larare-utbildningsforvaltningen. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/legitimerad-och-behorig-larare-utbildningsforvaltningen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:37',
#    'last_publication_date': '2024-07-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392957150},
#   {'relevance': 1.0,
#    'id': '28976559',
#    'external_id': '46-556656-5502-8872',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976559',
#    'logo_url': None,
#    'headline': 'Anna Whitlocks gymnasium söker lärare i historia eller...',
#    'application_deadline': '2024-07-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/anna-whitlocks-gymnasium-soker-larare-i-historia-eller-webbutveckling. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/anna-whitlocks-gymnasium-soker-larare-i-historia-eller-webbutveckling. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/anna-whitlocks-gymnasium-soker-larare-i-historia-eller-webbutveckling',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'f8q7_Rwv_TP4',
#     'label': 'Lärare i gymnasieskolan',
#     'legacy_ams_taxonomy_id': '7127'},
#    'occupation_group': {'concept_id': '4KhP_FxL_uZ5',
#     'label': 'Gymnasielärare',
#     'legacy_ams_taxonomy_id': '2330'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'f8q7_Rwv_TP4',
#       'label': 'Lärare i gymnasieskolan',
#       'legacy_ams_taxonomy_id': '7127'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:37',
#    'last_publication_date': '2024-07-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392957556},
#   {'relevance': 1.0,
#    'id': '28976556',
#    'external_id': '46-556656-5502-8864',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976556',
#    'logo_url': None,
#    'headline': 'Lärare textilslöjd',
#    'application_deadline': '2024-07-24T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-textilslojd. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/larare-textilslojd. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/larare-textilslojd',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'Ybj9_pTV_yi4',
#     'label': 'Slöjdare',
#     'legacy_ams_taxonomy_id': '3221'},
#    'occupation_group': {'concept_id': 'aKdV_u7V_R5j',
#     'label': 'Musikinstrumentmakare och övriga konsthantverkare',
#     'legacy_ams_taxonomy_id': '7319'},
#    'occupation_field': {'concept_id': 'PaxQ_o1G_wWH',
#     'label': 'Hantverk',
#     'legacy_ams_taxonomy_id': '6'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'Ybj9_pTV_yi4',
#       'label': 'Slöjdare',
#       'legacy_ams_taxonomy_id': '3221'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:36',
#    'last_publication_date': '2024-07-24T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392956428},
#   {'relevance': 1.0,
#    'id': '28976581',
#    'external_id': '46-556656-5502-8859',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976581',
#    'logo_url': None,
#    'headline': 'Engelbrektsskolan söker lärare i Ma/NO/Tk åk 4-6, 100%',
#    'application_deadline': '2024-08-04T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/engelbrektsskolan-soker-larare-i-manotk-ak-4-6-100. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/engelbrektsskolan-soker-larare-i-manotk-ak-4-6-100. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/engelbrektsskolan-soker-larare-i-manotk-ak-4-6-100',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:35',
#    'last_publication_date': '2024-08-04T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392955672},
#   {'relevance': 1.0,
#    'id': '28976577',
#    'external_id': '46-556656-5502-8852',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976577',
#    'logo_url': None,
#    'headline': 'Hjulsta Grundskola söker lärare i spanska 50%',
#    'application_deadline': '2024-07-26T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/hjulsta-grundskola-soker-larare-i-spanska-50. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/hjulsta-grundskola-soker-larare-i-spanska-50. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/hjulsta-grundskola-soker-larare-i-spanska-50',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'rgsj_poi_koz',
#     'label': 'Modersmålslärare i grundskolan',
#     'legacy_ams_taxonomy_id': '7314'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'rgsj_poi_koz',
#       'label': 'Modersmålslärare i grundskolan',
#       'legacy_ams_taxonomy_id': '7314'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:34',
#    'last_publication_date': '2024-07-26T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392954253},
#   {'relevance': 1.0,
#    'id': '28976574',
#    'external_id': '46-556656-5502-8746',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976574',
#    'logo_url': None,
#    'headline': 'Engagerad biträdande rektor åk 7-9 sökes till Sjöstadsskolan',
#    'application_deadline': '2024-07-22T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/engagerad-bitradande-rektor-ak-7-9-sokes-till-sjostadsskolan. Vi ser fram emot din ansökan!\n\n\n                        Sjöstadsskolan \n\nStockholm – vår huvudstad med miljoner drömmar, förväntningar och ambitioner. Vi jobbar för alla som lever här idag och i framtiden. Nu söker vi dig som vill tänka stort, nytt och annorlunda med oss – för stockholmarna.\nVälkommen till oss\nVälkommen att söka en heltidstjänst hos oss! Vi är en prisbelönt skola vackert belägen nära vattnet i Hammarby Sjöstad, en modern stadsdel som också räknas som en naturlig utvidgning av Stockholms innerstad. Skolan ligger i Luma park i Sjöstaden, med närhet till skog och friluftsområden. Skolan har i nuläget runt 960 elever i skolåren F-9 i grundskolan samt årskurs 1-9 i anpassad grundskola. Sjöstadsskolan vill vara den bästa skolan för varje elev. Här ges en högkvalitativ undervisning i en trygg lärmiljö med tillgängliga lärmiljöer och värdegrundsarbete som fokus.\xa0På så vis säkerställer vi att undervisningen håller hög kvalitet. Skolan arbetar med forskning och utveckling av undervisningen och digitalisering och har fått ett flertal utmärkelser för sin verksamhet. Sjöstadsskolans vision bygger på följande ledord:\n• Jag visar respekt och har höga förväntningar på mig själv.\n• Jag visar respekt mot andra och vår gemensamma miljö.\n• Tillsammans skapar vi en välmående och glädjefylld skola för alla.\nDin roll\nVi söker dig som vill förvalta och förädla Sjöstadsskolans välfungerande högstadium. Vi har för närvarande 13 klasser i åk 7-9, uppdelade i tre lag. Eleverna undervisas av arbetslag bestående av kompetenta och erfarna lärare med stöd av flera resurspersoner.\xa0\nÄmneskunniga lärare samverkar kring utveckling av ämnet från förskoleklass till årskurs 9. Arbetslagen ansvarar för att eleverna ska känna sig trygga, bemötas likvärdigt och vara delaktiga i verksamhetens utformning. Digitala lärverktyg gör det möjligt att både utmana elever och att ge extra stöd. Det finns därför interaktiva tavlor i alla klassrum, en dator per elev från årskurs 4 och lärplattor till de yngsta eleverna.\nSom biträdande rektor med ansvar för högstadiet är du en del av Sjöstadsskolans ledningsgrupp vilket innebär att du förväntas bidra till skolans fortsatta utveckling utifrån högt satta mål för hela skolan. Som biträdande rektor samarbetar du med elevhälsoteamet för elevernas bästa.\xa0Genom att ha APT med dina närmaste medarbetare ingår du i samverkansgruppen på skolan. Arbetet som biträdande rektor innebär personalansvar för olika yrkeskategorier. Du leder och coachar dina medarbetare i ett nära ledarskap. I gott samarbete verkar du för att skolan uppfyller gemensamt framtagna mål och att den utbildning vi ger eleverna håller högsta kvalitet.\nMer specifikt kommer du i rollen bland annat att ansvara för:\nMåluppfyllelse och kvalitet inklusive det systematiska kvalitetsarbetet för de årskurser du har ansvar för.\nPersonalansvar (t ex medarbetarsamtal)\nAtt leda, samordna och utveckla det pedagogiska arbetet i arbetslagen\nAtt ledas skolans värdegrundsarbete\nElevhälsoarbete och trygghetsarbetet för eleverna i årskurs 7-9\xa0\nDu ingår i skolans ledningsgrupp som består av fyra biträdande rektorer, en administrativ chef och rektor. Genom ett inkluderande förhållningssätt skapar du, tillsammans med lärare och arbetslaget, en undervisning som är anpassad till alla våra elever.\nDin kompetens och erfarenhet\nVi söker dig som är lyhörd, uppmärksam och tar initiativ till att utveckla verksamheten. Du har god förmåga att strukturera, planera och organisera arbetet och verksamheten. Vidare är du väl insatt i det systematiska kvalitetsarbetet och hittar former för att bedriva ett kontinuerligt uppföljnings- och utvecklingsarbet ...
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/engagerad-bitradande-rektor-ak-7-9-sokes-till-sjostadsskolan. Vi ser fram emot din ansökan!\n\n\n                        Sjöstadsskolan \n\nStockholm – vår huvudstad med miljoner drömmar, förväntningar och ambitioner. Vi jobbar för alla som lever här idag och i framtiden. Nu söker vi dig som vill tänka stort, nytt och annorlunda med oss – för stockholmarna.\nVälkommen till oss\nVälkommen att söka en heltidstjänst hos oss! Vi är en prisbelönt skola vackert belägen nära vattnet i Hammarby Sjöstad, en modern stadsdel som också räknas som en naturlig utvidgning av Stockholms innerstad. Skolan ligger i Luma park i Sjöstaden, med närhet till skog och friluftsområden. Skolan har i nuläget runt 960 elever i skolåren F-9 i grundskolan samt årskurs 1-9 i anpassad grundskola. Sjöstadsskolan vill vara den bästa skolan för varje elev. Här ges en högkvalitativ undervisning i en trygg lärmiljö med tillgängliga lärmiljöer och värdegrundsarbete som fokus.\xa0På så vis säkerställer vi att undervisningen håller hög kvalitet. Skolan arbetar med forskning och utveckling av undervisningen och digitalisering och har fått ett flertal utmärkelser för sin verksamhet. Sjöstadsskolans vision bygger på följande ledord:\n• Jag visar respekt och har höga förväntningar på mig själv.\n• Jag visar respekt mot andra och vår gemensamma miljö.\n• Tillsammans skapar vi en välmående och glädjefylld skola för alla.\nDin roll\nVi söker dig som vill förvalta och förädla Sjöstadsskolans välfungerande högstadium. Vi har för närvarande 13 klasser i åk 7-9, uppdelade i tre lag. Eleverna undervisas av arbetslag bestående av kompetenta och erfarna lärare med stöd av flera resurspersoner.\xa0\nÄmneskunniga lärare samverkar kring utveckling av ämnet från förskoleklass till årskurs 9. Arbetslagen ansvarar för att eleverna ska känna sig trygga, bemötas likvärdigt och vara delaktiga i verksamhetens utformning. Digitala lärverktyg gör det möjligt att både utmana elever och att ge extra stöd. Det finns därför interaktiva tavlor i alla klassrum, en dator per elev från årskurs 4 och lärplattor till de yngsta eleverna.\nSom biträdande rektor med ansvar för högstadiet är du en del av Sjöstadsskolans ledningsgrupp vilket innebär att du förväntas bidra till skolans fortsatta utveckling utifrån högt satta mål för hela skolan. Som biträdande rektor samarbetar du med elevhälsoteamet för elevernas bästa.\xa0Genom att ha APT med dina närmaste medarbetare ingår du i samverkansgruppen på skolan. Arbetet som biträdande rektor innebär personalansvar för olika yrkeskategorier. Du leder och coachar dina medarbetare i ett nära ledarskap. I gott samarbete verkar du för att skolan uppfyller gemensamt framtagna mål och att den utbildning vi ger eleverna håller högsta kvalitet.\nMer specifikt kommer du i rollen bland annat att ansvara för:\nMåluppfyllelse och kvalitet inklusive det systematiska kvalitetsarbetet för de årskurser du har ansvar för.\nPersonalansvar (t ex medarbetarsamtal)\nAtt leda, samordna och utveckla det pedagogiska arbetet i arbetslagen\nAtt ledas skolans värdegrundsarbete\nElevhälsoarbete och trygghetsarbetet för eleverna i årskurs 7-9\xa0\nDu ingår i skolans ledningsgrupp som består av fyra biträdande rektorer, en administrativ chef och rektor. Genom ett inkluderande förhållningssätt skapar du, tillsammans med lärare och arbetslaget, en undervisning som är anpassad till alla våra elever.\nDin kompetens och erfarenhet\nVi söker dig som är lyhörd, uppmärksam och tar initiativ till att utveckla verksamheten. Du har god förmåga att strukturera, planera och organisera arbetet och verksamheten. Vidare är du väl insatt i det systematiska kvalitetsarbetet och hittar former för att bedriva ett kontinuerligt uppföljnings- och utvecklingsarbete.\nT ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/engagerad-bitradande-rektor-ak-7-9-sokes-till-sjostadsskolan',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'hr5f_dci_NcD',
#     'label': 'Rektor',
#     'legacy_ams_taxonomy_id': '3422'},
#    'occupation_group': {'concept_id': 'z8di_AqX_GBr',
#     'label': 'Chefer inom grund- och gymnasieskola samt vuxenutbildning',
#     'legacy_ams_taxonomy_id': '1410'},
#    'occupation_field': {'concept_id': 'bh3H_Y3h_5eD',
#     'label': 'Chefer och verksamhetsledare',
#     'legacy_ams_taxonomy_id': '20'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'hr5f_dci_NcD',
#       'label': 'Rektor',
#       'legacy_ams_taxonomy_id': '3422'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:33',
#    'last_publication_date': '2024-07-22T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392953302},
#   {'relevance': 1.0,
#    'id': '28976575',
#    'external_id': '46-556656-5502-8747',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976575',
#    'logo_url': None,
#    'headline': 'Vikarierande legitimerad lärare i sv och ma åk 6',
#    'application_deadline': '2024-07-23T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/vikarierande-legitimerad-larare-i-sv-och-ma-ak-6. Vi ser fram emot din ansökan!',
#     'text_formatted': 'För dig som läser detta vill vi på Netjobs Group AB informera om att vi endast tar emot ansökningar via vår hemsida, inte via e-post eller telefon. För att ansöka till tjänsten, vänligen besök https://karriarguiden.se/sv/jobb/vikarierande-legitimerad-larare-i-sv-och-ma-ak-6. Vi ser fram emot din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://karriarguiden.se/sv/arbetsgivare/stockholms-stad-utbildningsforvaltningen',
#     'organization_number': '5566565502',
#     'name': 'Netjobs Group AB',
#     'workplace': 'Stockholms stad - Utbildningsförvaltningen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriarguiden.se/sv/jobb/vikarierande-legitimerad-larare-i-sv-och-ma-ak-6',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-19T14:42:33',
#    'last_publication_date': '2024-07-23T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1721392953626},
#   {'relevance': 1.0,
#    'id': '28976573',
#    'external_id': '46-556656-5502-8742',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28976573',
#    'logo_url': None,
#    'headline': 'Lärare mot fritidshem inriktning Idrott och hälsa',
#    'application_deadline': '2024-08-05T23:59:59',
#    'number_of_vacancies': 1,
# ...
#     'text_formatted': '<p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt;"><span style="font-size: 11pt; font-family: Arial, sans-serif; color: rgb(0, 0, 0); background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><i>Internationella Engelska Skolan (IES) is a leading independent school group with academic results far above average and a diverse and energetic staff. Teaching is in both Swedish and English, and the hallways are bilingual. The language of meetings and communication amongst the staff is English.</i></span></p><p dir="ltr" style="line-height:1.38;background-color:#ffffff;margin-top:0pt;margin-bottom:0pt;padding:0pt 0pt 8pt 0pt;"><span id="docs-internal-guid-d3d38a79-7fff-6485-09a0-9f5d477150f6"><i><br></i></span></p><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt;"><span style="font-size: 11pt; font-family: Arial, sans-serif; color: rgb(0, 0, 0); background-color: transparent; font-weight: 400; font-variant: normal; text-decoration: none; vertical-align: baseline; white-space: pre-wrap;"><i>IES is one of Sweden\'s largest school groups at compulsory school level with 48 schools and around 32,000 students across the country. IES has grown steadily and maintained quality since 1993.</i></span></p>\r\n\r\nInternationella Engelska Skolan (IES) har gjort stor skillnad för våra elever under de senaste 30 åren. Vi tror att vår framgång beror på vårt tydliga etos med engagerade och närvarande ledare som skapar en miljö där lärare kan undervisa och elever kan lära sig. Vi har en stark kultur som bygger på beprövade rutiner där bemötandet är självklart. Hos oss får lärare fokusera på undervisning och lärande, med eleverna i centrum för allt vi gör.\n\nIES Hässelby är en skola för årskurserna 4-9 med ca 570 elever och 60 medarbetare. Vi är en tvåspråkig skola som följer den svenska läroplanen. Skolan ligger i Hässelby, strax utanför Stockholm, en kort promenad från Grimsta naturreservat, vackra Mälaren och Hässelby strands tunnelbanestation.\n\nAtt arbeta i vår skola innebär att vara en del av en professionell gemenskap där du får möjlighet att utforska världen på hemmaplan. På IES Hässelby har du möjlighet att utvecklas i olika roller.\n\nVi söker nu en behörig lärare i Sv/SVA för åk 7-9. Tjänsten är tillsvidare med start 7 augusti 2024.\n\nAnsvarsområden:\n\n- Planera och genomföra lektioner\n- Bedöma elevens framsteg, ge konstruktiv feedback och föra noggranna dokumentationer\n- Mentorskap för elever i en av de klasserna du undervisar\n- Samarbeta med kollegor för att skapa en stödjande och inkluderande lärmiljö\n- Delta i professionell utveckling och bidra till skolans gemenskap\n\nKvalifikationer:\n\n- Lärarlegitimation\n- Goda kunskaper i svenska och engelska\n- Positiv attityd och samarbetsvillig\n- Förmåga att anpassa undervisningsmetoder för att möta elevernas olika behov\n- Engagemang för kontinuerlig professionell utveckling och lärande\n\nHur du ansöker:\n\nOm du är passionerad när det kommer till undervisning och redo att vara en del av ett internationellt team, uppmanar vi dig att ansöka genom att skicka in ditt CV och ett personligt brev via IES Careers. \n\nRekryteringen pågår löpande, så skicka in din ansökan så snart som möjligt.\n\nVälkommen med din ansökan till IES Hässelby, där du har möjlighet att göra skillnad i elevernas liv varje dag!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Full time\r\nPermanent with probation'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Fixed salary',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://hasselby.engelska.se',
#     'organization_number': '5564624368',
#     'name': 'Internationella Engelska Skolan i Sverige AB',
#     'workplace': 'Internationella Engelska Skolan Hässelby'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://apply.engelska.se/vacancy/kZN2KLvSTZ9sNeEEk',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Amanda Fogelquist',
#      'email': 'recruitment.hasselby@engelska.se',
#      'telephone': '08-522 482 00',
#      'contact_type': None}],
#    'publication_date': '2024-06-25T11:02:30',
#    'last_publication_date': '2024-07-25T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1719306560772},
#   {'relevance': 1.0,
#    'id': '28920260',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28920260',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/arbetsplatser/81669059/logotyper/logo.png',
#    'headline': 'Legitimerad lärare i geografi och samhällskunskap',
#    'application_deadline': '2024-11-03T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Om oss\nStefanskolan är en kristen friskola med årskurs F-9. Skolan är belägen i det trevliga området Ängbyplan i Bromma. Ett trivsamt, lugnt och tryggt område med goda parkeringsmöjligheter och nära tunnelbana.\nStefanskolan arbetar aktivt med likabehandlingsplanen och har nolltolerans mot mobbning för att skapa en trevlig atmosfär och personlig omsorg för barnens bästa.\nVi tror att goda kunskaper är vägen till framgång. Med kunskap om olika lärostilar arbetar vi aktivt för att alla barn ska bli bra på att läsa, skriva och räkna. Elevhälsoarbetet är högt prioriterat och vi har ett härligt och engagerat elevhälsoteam som älskar att göra skillnad för våra elever och som dessutom ges förutsättning för det. \nVi söker\nNu söker vi en legitimerad lärare i geografi och samhällskunskap för åk 4-9. Tjänsten är ungefär 25 %. Mindre justeringar av omfattning kan diskuteras. \nVi har positiv tillväxt och har stora ambitioner och därför bör du tycka om att vara del i att påverka, förbättra och tillsammans med andra bidra till att göra skolan än mer fantastisk. \nSkolan präglas av ett gott klimat, engagemang och värme. \nDina kvalifikationer\nVi lägger stor vikt vid personliga egenskaper och ser gärna att du delar vår värdegrund. Du ska ha ett stort engagemang och tålamod, vara välplanerad samt ha struktur över dagen och alltid vara steget före. Du ska:\n·      vara behörig eller kommer att bli behörig \n·      ha erfarenhet som grundskolelärare\n·      vara trygg och tydlig i din roll och skapa god studiero. \n·      tycka om och ha förmåga att skapa bra relationer med elever och vuxna\n·      älska att göra skillnad för våra elever, att ge dem en god grund och alltid värna deras potential och integritet.\nVi tar emot ansökningar men kommer pausa intervjuer i juli månad.\nLön\nMånadslön enligt överenskommelse.\nArbetstid\n25 %. Vi tillämpar provanställning.\nAnsökan\nVi tar endast emot ansökningar via mail.\nSkicka ansökan till: jobbssk@petrusgruppen.se\nOBS. skriv ”ansökan geografi och samhällskunskap” som meddelande i mailet.\nRekryteringsarbetet kommer att ske löpande, tillsättning till hösten.',
#     'text_formatted': '<p><br></p><p><strong> </strong></p><p><strong>Om oss</strong></p><p>Stefanskolan är en kristen friskola med årskurs F-9. Skolan är belägen i det trevliga området Ängbyplan i Bromma. Ett trivsamt, lugnt och tryggt område med goda parkeringsmöjligheter och nära tunnelbana.</p><p>Stefanskolan arbetar aktivt med likabehandlingsplanen och har nolltolerans mot mobbning för att skapa en trevlig atmosfär och personlig omsorg för barnens bästa.</p><p>Vi tror att goda kunskaper är vägen till framgång. Med kunskap om olika lärostilar arbetar vi aktivt för att alla barn ska bli bra på att läsa, skriva och räkna. Elevhälsoarbetet är högt prioriterat och vi har ett härligt och engagerat elevhälsoteam som älskar att göra skillnad för våra elever och som dessutom ges förutsättning för det. </p><p><strong>Vi söker</strong></p><p>Nu söker vi en legitimerad lärare i geografi och samhällskunskap för åk 4-9. Tjänsten är ungefär 25 %. Mindre justeringar av omfattning kan diskuteras. </p><p>Vi har positiv tillväxt och har stora ambitioner och därför bör du tycka om att vara del i att påverka, förbättra och tillsammans med andra bidra till att göra skolan än mer fantastisk. </p><p>Skolan präglas av ett gott klimat, engagemang och värme. </p><p><strong>Dina kvalifikationer</strong></p><p>Vi lägger stor vikt vid personliga egenskaper och ser gärna att du delar vår värdegrund. Du ska ha ett stort engagemang och tålamod, vara välplanerad samt ha struktur över dagen och alltid vara steget före. Du ska:</p><p>·      vara behörig eller kommer att bli behörig </p><p>·      ha erfarenhet som grundskolelärare</p><p>·      vara trygg och tydlig i din roll och skapa god studiero. </p><p>·      tycka om och ha förmåga att skapa bra relationer med elever och vuxna</p><p>·      älska att göra skillnad för våra elever, att ge dem en god grund och alltid värna deras potential och integritet.</p><p>Vi tar emot ansökningar men kommer pausa intervjuer i juli månad.</p><p><strong>Lön</strong></p><p>Månadslön enligt överenskommelse.</p><p><strong>Arbetstid</strong></p><p>25 %. Vi tillämpar provanställning.</p><p><strong>Ansökan</strong></p><p>Vi tar endast emot ansökningar via mail.</p><p>Skicka ansökan till: <strong>jobbssk@petrusgruppen.se</strong></p><p><strong>OBS. skriv ”ansökan geografi och samhällskunskap” som meddelande i mailet.</strong></p><p>Rekryteringsarbetet kommer att ske löpande, tillsättning till hösten.</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '8020094994',
#     'name': 'Fören Stefanskolan',
#     'workplace': 'Stefanskolan, Fören'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': 'jobbssk@petrusgruppen.se',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Tegnebyvägen 30',
#     'postcode': '16855',
#     'city': 'Ängbyplan',
#     'coordinates': [17.908401562550967, 59.345188881216544]},
#    'must_have': {'skills': [],
#     'languages': [{'weight': 10,
#       'concept_id': 'zSLA_vw2_FXN',
#       'label': 'Svenska',
#       'legacy_ams_taxonomy_id': '502'}],
#     'work_experiences': [],
#     'education': [{'weight': 10,
#       'concept_id': 'tFCz_HSa_jwW',
#       'label': 'Pedagogik och lärarutbildning',
#       'legacy_ams_taxonomy_id': '4'}],
#     'education_level': [{'weight': 10,
#       'concept_id': 'asZm_TEQ_Srk',
#       'label': 'Eftergymnasial utbildning två år eller längre',
#       'legacy_ams_taxonomy_id': '6'}]},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-06-25T10:53:03',
#    'last_publication_date': '2024-11-03T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1719305583255}]}

# %%
response_json.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
len(response_json["hits"])
# Out:
# 100

# %%
response_json["hits"][1]["headline"]
# Out:
# 'Lärare Trä- och metallslöjd åk 3-9'

# %%
response_json = _get_ads({'q': "data engineer", 'limit': 100})
response_json
# Out:
# {'total': {'value': 68},
#  'positions': 98,
#  'query_time_in_millis': 6,
#  'result_time_in_millis': 259,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['data engineer'],
#   'location': [],
#   'skill_must': [],
#   'occupation_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '28969097',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28969097',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/arbetsplatser/88097616/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-08-15T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': "At Sandvik Group IT, we’re looking for a Data Engineer with strong technical skills to join us on an exciting transformation journey and build a new modern Azure data platform.\nYou’ll be part of a diverse and collaborative team with a focus on building scalable and secured middle layer serving data to the front services.\nSome words about us\nAt Sandvik, we're going through a major digital shift with the objective of becoming an industry leader within digital solutions and to enable operational excellence through digitalization. We welcome you to an open and supportive work environment where you get to grow and develop – read more about our culture on our career site! We look forward to hearing from you!\nYour mission\nYour main focus is leading the exciting mission of building data pipelines to onboard data from various sources, such as relational databases, mainframe systems, APIs, and message queues. With Azure Cloud Platform as your targeted working environment, you develop scalable and secure services that harvest integrated data.\nYou have a strong voice in decision-making and our technical road map, and your work highly contributes to meeting data compliance and governance standards. You shape our work culture by sharing your knowledge, coaching junior developers, and partnering with the business, as you deploy data pipelines that deliver value and insights from data. \nThis position is based in Sandviken or Stockholm, Sweden and allows for a hybrid work schedule.\nYour profile\nWe’re looking for a seasoned data engineer who can handle complex data challenges in an agile environment. You have:\nA strong grasp of SQL and Python, and you can use Spark and Azure data bricks to build and manage scalable data solutions.\nFamiliarity with various data architectures, such as Data Lake, Data Mesh, and Data Fabric, and you can design and implement data pipelines that integrate data from multiple sources, such as databases, flat files, API’s, and event-driven data feeds.\nProficiency in software development practices, such as Git version control, CI/CD, and Docker, and you can troubleshoot and optimize data pipelines for enhanced performance and reliability.\nFluency in English.\n\nAlthough your hard skills are important, we highly value your personality – characterized by your forward-thinking mindset, helping you to drive change and continuous improvement across teams, tools, and processes. You’re comfortable communicating and building relationships with stakeholders at all over our organization and have the ability to easily “grasp the gist”.  With your analytical mindset, you’re able to approach complex challenges and proactively tackle them with your team's help. You have a positive and open mind, and as a true team player, you’re intrigued by collaborating and motivating other team members in a multicultural environment.\nOur culture\nAt Sandvik, we’re tech driven, innovative and entrepreneurial. We believe that success is a team effort so we value diversity and are committed to creating an inclusive culture where people can be themselves and reach their full potential. So, we invest in supporting each other, learning together and celebrating our differences. Visit our stories hub, LinkedIn or Facebook to get to know us further.\nContact information\nFor further information about this position, please contact:\nSwati Falak, recruiting manager, swati.falak@sandvik.com\nWe have already decided on which advertising channels and marketing campaigns we wish to use, and respectfully decline any additional contacts in that matter.\nUnion contacts – Sweden\nAnders Rönnqvist, Unionen, +46 (0)70 616 41 21\nGöran Norell, Akademikerföreningen, +46 (0)70 616 43 78\nPeter Olsson-Andrée, Ledarna, +46 (0)70 222 48 55\nRecruitment Specialist\nGustaf Sjögren\nHow to apply\nSend your application no later than August 15, 2024. Click apply and include your resume and cover letter in English. Please note that we don’ ...
#     'text_formatted': "<p>At Sandvik Group IT, we’re looking for a Data Engineer with strong technical skills to join us on an exciting transformation journey and build a new modern Azure data platform.</p><p>You’ll be part of a diverse and collaborative team with a focus on building scalable and secured middle layer serving data to the front services.</p><p>Some words about us</p><p>At Sandvik, we're going through a major digital shift with the objective of becoming an industry leader within digital solutions and to enable operational excellence through digitalization. We welcome you to an open and supportive work environment where you get to grow and develop – read more about our culture on our career site! We look forward to hearing from you!</p><p>Your mission</p><p>Your main focus is leading the exciting mission of building data pipelines to onboard data from various sources, such as relational databases, mainframe systems, APIs, and message queues. With Azure Cloud Platform as your targeted working environment, you develop scalable and secure services that harvest integrated data.</p><p>You have a strong voice in decision-making and our technical road map, and your work highly contributes to meeting data compliance and governance standards. You shape our work culture by sharing your knowledge, coaching junior developers, and partnering with the business, as you deploy data pipelines that deliver value and insights from data. </p><p>This position is based in Sandviken or Stockholm, Sweden and allows for a hybrid work schedule.</p><p>Your profile</p><p>We’re looking for a seasoned data engineer who can handle complex data challenges in an agile environment. You have:</p><ul><li>A strong grasp of SQL and Python, and you can use Spark and Azure data bricks to build and manage scalable data solutions.</li><li>Familiarity with various data architectures, such as Data Lake, Data Mesh, and Data Fabric, and you can design and implement data pipelines that integrate data from multiple sources, such as databases, flat files, API’s, and event-driven data feeds.</li><li>Proficiency in software development practices, such as Git version control, CI/CD, and Docker, and you can troubleshoot and optimize data pipelines for enhanced performance and reliability.</li><li>Fluency in English.</li></ul><p>Although your hard skills are important, we highly value your personality – characterized by your forward-thinking mindset, helping you to drive change and continuous improvement across teams, tools, and processes. You’re comfortable communicating and building relationships with stakeholders at all over our organization and have the ability to easily “grasp the gist”.  With your analytical mindset, you’re able to approach complex challenges and proactively tackle them with your team's help. You have a positive and open mind, and as a true team player, you’re intrigued by collaborating and motivating other team members in a multicultural environment.</p><p>Our culture</p><p>At Sandvik, we’re tech driven, innovative and entrepreneurial. We believe that success is a team effort so we value diversity and are committed to creating an inclusive culture where people can be themselves and reach their full potential. So, we invest in supporting each other, learning together and celebrating our differences. Visit our stories hub, LinkedIn or Facebook to get to know us further.</p><p>Contact information</p><p>For further information about this position, please contact:</p><p>Swati Falak, recruiting manager, swati.falak@sandvik.com</p><p>We have already decided on which advertising channels and marketing campaigns we wish to use, and respectfully decline any additional contacts in that matter.</p><p>Union contacts – Sweden</p><p>Anders Rönnqvist, Unionen, +46 (0)70 616 41 21</p><p>Göran Norell, Akademikerföreningen, +46 (0)70 616 43 78</p><p>Peter Olsson-Andrée, Ledarna, +46 (0)70 222 48 55</p><p>Recruitment Specialist</p><p>Gustaf Sjögren</p><p>How to a ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5560003468',
#     'name': 'SANDVIK AB',
#     'workplace': 'Gasverket Stockholm'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://sandvik.wd3.myworkdayjobs.com/sandvik-jobs/job/Sweden-Stockholm/Data-Engineer_R0066184-1',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Storviltsgatan 10',
#     'postcode': '11547',
#     'city': 'Stockholm',
#     'coordinates': [18.08992727678008, 59.358786592926045]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-15T14:18:40',
#    'last_publication_date': '2024-08-15T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1721119276677},
#   {'relevance': 1.0,
#    'id': '28963232',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28963232',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/arbetsplatser/87420686/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-10-09T23:59:59',
#    'number_of_vacancies': 5,
#    'description': {'text': 'Telescope Services AB har sedan 1999 jobbat med att rekrytera de främsta mjukvaruspecialisterna från hela världen. Vårt huvudkontor ligger i Lund, med rekryteringsnoder i mer än tio länder, och vi är idag ca 100 medarbetare på plats här i Sverige. \nWhat you’ll do:\nAs a Data Engineer, you will support and contribute to the development of products aimed at enhancing business decision-making capabilities, ensuring alignment with clients standards, best practices, and utilizing data and analytics tools support.\nWe believe that your background and skills include:\nData Engineering\nAzure Blob Storage\nSnowflake incl Snowflake admin\nSQL \n\nPlease send Your CV to jobs@telescopeservices.se.',
#     'text_formatted': '<p><em>Telescope Services AB har sedan 1999 jobbat med att rekrytera de främsta mjukvaruspecialisterna från hela världen. Vårt huvudkontor ligger i Lund, med rekryteringsnoder i mer än tio länder, och vi är idag ca 100 medarbetare på plats här i Sverige. </em></p><p><strong>What you’ll do:</strong></p><p>As a Data Engineer, you will support and contribute to the development of products aimed at enhancing business decision-making capabilities, ensuring alignment with clients standards, best practices, and utilizing data and analytics tools support.</p><p><strong>We believe that your background and skills include:</strong></p><ul><li>Data Engineering</li><li>Azure Blob Storage</li><li>Snowflake incl Snowflake admin</li><li>SQL </li></ul><p><strong>Please send Your CV to jobs@telescopeservices.se.</strong></p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5568072820',
#     'name': 'Telescope Services AB',
#     'workplace': 'Telescope Services AB'},
#    'application_details': {'information': None,
#     'reference': 'TSS-DAE-240401',
#     'email': 'jobs@telescopeservices.se',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'fciS_GRw_wk5',
#     'label': 'Dataoperatör',
#     'legacy_ams_taxonomy_id': '6027'},
#    'occupation_group': {'concept_id': '13md_uyV_BNG',
#     'label': 'Drifttekniker, IT',
#     'legacy_ams_taxonomy_id': '3511'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Lund',
#     'municipality_code': '1281',
#     'municipality_concept_id': 'muSY_tsR_vDZ',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Scheelevägen 16',
#     'postcode': '22363',
#     'city': 'Lund',
#     'coordinates': [13.219470810922534, 55.71509704496216]},
#    'must_have': {'skills': [],
#     'languages': [{'weight': 10,
#       'concept_id': 'NVxJ_hLg_TYS',
#       'label': 'Engelska',
#       'legacy_ams_taxonomy_id': '283'}],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'fciS_GRw_wk5',
#       'label': 'Dataoperatör',
#       'legacy_ams_taxonomy_id': '6027'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-11T12:01:00',
#    'last_publication_date': '2024-10-09T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1720692060430},
#   {'relevance': 1.0,
#    'id': '28720058',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28720058',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-08-09T23:59:59',
#    'number_of_vacancies': 3,
#    'description': {'text': 'Bachelors or Masters degree required in Mathematics or Computer Science.\nExperience Required: 7+ years\nExcellent Problem Solving Skills\nExperience in Banking, finance, insurance and E-commerce domain is \nExperience in Micro services technologies using Java 8 Spring framework\nDeep understanding of a micro services architecture including professional experience in the design build and operations of micro services in a production environment\nExperience designing REST APIs and implementing RESTful web services\nExperience in designing data persistence system using both SQL and NoSQL DBMS MongoDB OracleDB \nGood understanding of SCRUM Agile methodology\n\n\n\nJava 8\nSpring Framework\nSpring Boot\nNetflix OSS\nPython\nHibernate\nOstrich\nGradle and Maven\nUnix\nGitHub\nJMeter\nJenkins\nActive MQ\nPostman\nJSON\nWildfly\nPostgreSQL / MySQL / OracleDB\nReactJS\nDocker\nKubernetes\nGraphQL\nIstio\nKafka\nC++\nCassandra\nAngular JS\nRabbit MQ\nAxon Framework\n\n\n\nÖppen för alla\nVi fokuserar på din kompetens, inte dina övriga förutsättningar. Vi är öppna för att anpassa rollen eller arbetsplatsen efter dina behov.',
#     'text_formatted': '<ul><li>Bachelors or Masters degree required in Mathematics or Computer Science.</li><li>Experience Required: 7+ years</li><li>Excellent Problem Solving Skills</li><li>Experience in Banking, finance, insurance and E-commerce domain is </li><li>Experience in Micro services technologies using Java 8 Spring framework</li><li>Deep understanding of a micro services architecture including professional experience in the design build and operations of micro services in a production environment</li><li>Experience designing REST APIs and implementing RESTful web services</li><li>Experience in designing data persistence system using both SQL and NoSQL DBMS MongoDB OracleDB </li><li>Good understanding of SCRUM Agile methodology</li></ul><p><br></p><ul><li>Java 8</li><li>Spring Framework</li><li>Spring Boot</li><li>Netflix OSS</li><li>Python</li><li>Hibernate</li><li>Ostrich</li><li>Gradle and Maven</li><li>Unix</li><li>GitHub</li><li>JMeter</li><li>Jenkins</li><li>Active MQ</li><li>Postman</li><li>JSON</li><li>Wildfly</li><li>PostgreSQL / MySQL / OracleDB</li><li>ReactJS</li><li>Docker</li><li>Kubernetes</li><li>GraphQL</li><li>Istio</li><li>Kafka</li><li>C++</li><li>Cassandra</li><li>Angular JS</li><li>Rabbit MQ</li><li>Axon Framework</li></ul><p><br></p><p id="oppenforalla">Öppen för alla\nVi fokuserar på din kompetens, inte dina övriga förutsättningar. Vi är öppna för att anpassa rollen eller arbetsplatsen efter dina behov.</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'www.owision.com',
#     'organization_number': '5591714711',
#     'name': 'owision AB',
#     'workplace': 'owision AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': 'hr@owision.com',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '7wdX_4rv_33z',
#     'label': 'Backend-utvecklare',
#     'legacy_ams_taxonomy_id': '7632'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Tyresö',
#     'municipality_code': '0138',
#     'municipality_concept_id': 'sTPc_k2B_SqV',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Grepvägen 1',
#     'postcode': '13543',
#     'city': 'Tyresö',
#     'coordinates': [18.239593295866737, 59.241705307809006]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [{'weight': 5,
#       'concept_id': 'NVxJ_hLg_TYS',
#       'label': 'Engelska',
#       'legacy_ams_taxonomy_id': '283'}],
#     'work_experiences': [{'weight': 5,
#       'concept_id': '7wdX_4rv_33z',
#       'label': 'Backend-utvecklare',
#       'legacy_ams_taxonomy_id': '7632'}],
#     'education': [{'weight': 5,
#       'concept_id': 'FHxz_HhN_3Mk',
#       'label': 'Data',
#       'legacy_ams_taxonomy_id': '14'}],
#     'education_level': [{'weight': 5,
#       'concept_id': 'SdS6_SLL_mRJ',
#       'label': 'Forskarutbildning',
#       'legacy_ams_taxonomy_id': '7'}]},
#    'application_contacts': [],
#    'publication_date': '2024-07-10T16:45:30',
#    'last_publication_date': '2024-08-09T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1720622730428},
#   {'relevance': 1.0,
#    'id': '28960857',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28960857',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-10-01T23:59:59',
#    'number_of_vacancies': 3,
#    'description': {'text': 'We’re looking for a skilled and motivated Data Engineer to join our dynamic team. In this crucial role, you will be instrumental in fostering a data-driven culture across our organisation, enabling departments to leverage data comprehensively and facilitating data teams in building models, AI, and machine learning solutions.\n\n\nYour expertise will drive the development and maintenance of our state-of-the-art cloud-based data platform, which is central to powering our globally recognized brand. In this role, you will see a direct correlation between your work, company growth, and user satisfaction.\n \nYOU WILL BE RESPONSIBLE FOR:\n\n\nBuild and maintain highly scalable and robust data management systems tailored to specific business needs and challenges.\nEnsure systems meet business requirements and industry practices for data integrity, security, and accessibility.\nBuild, maintain, develop, test, deploy and enhance our data pipelines and systems\nCollaborate with data team and stakeholders including data architects, Executive and Product from the beginning to the delivery of a project \nEnsure the highest quality of data is made available throughout the entire organisation and systems meeting our SLAs\n\n\n\nOUR SUCCESSFUL CANDIDATE WILL HAVE:\n\n\nESSENTIAL SKILLS:\nExperience working in an online, gaming, or fast-moving industry \n3+ years of work experience in data engineers and data platforms\nMust have experience in successfully implementing data-centric applications, such as data warehouses, operational data stores, and data integration projects  \nExperience with SQL, ETL, data modelling, and Python\nProven experience with Bigquery\nProficient with one or more big data & new data technologies such as DBT, Apache NiFi, Airflow, Kafka \n \n\nNICE TO HAVES:\nExperience from the iGaming industry is meriting\n\n\n\n\n\nWHO WE ARE\nAt the core of LeoVegas Group, is Team Leo. Our culture is our foundation and is what enables us to innovate, build, and lead as we trailblaze our way through the igaming industry. We’re a team of over 1400 innovators, initiators, and groundbreakers working in a fast-paced and agile environment across 11 offices world-wide.\n \nBENEFITS\n\n\nHybrid work policy\n4 weeks of Workation (T&C apply)\n30 annual vacation days\nOccupational Pension\n5,000 SEK wellness contribution annually\nParental Leave Top-Up\nPossibility to enrol in a private health care insurance for both you and your partner\n1,500 SEK equipment allowance\nBenify - benefits portal with many offers and discounts\nWe offer a relocation package with accommodation and flights.\n\n\n\nJOIN US!\nIn our pride, we like to empower our teammates to find their roar and run with their wildest ideas. We don’t wait around for things to happen, we pounce and make it happen!\n \nWould you be a good fit for the Leo Pride - give us a roar!\n \n**As our company working language is English we’d like to see your CV in English please**',
#     'text_formatted': '<p><br></p><p>We’re looking for a skilled and motivated Data Engineer to join our dynamic team. In this crucial role, you will be instrumental in fostering a data-driven culture across our organisation, enabling departments to leverage data comprehensively and facilitating data teams in building models, AI, and machine learning solutions.</p><p><br></p><p>Your expertise will drive the development and maintenance of our state-of-the-art cloud-based data platform, which is central to powering our globally recognized brand. In this role, you will see a direct correlation between your work, company growth, and user satisfaction.</p><p> </p><p><strong>YOU WILL BE RESPONSIBLE FOR:</strong></p><p><br></p><ul><li>Build and maintain highly scalable and robust data management systems tailored to specific business needs and challenges.</li><li>Ensure systems meet business requirements and industry practices for data integrity, security, and accessibility.</li><li>Build, maintain, develop, test, deploy and enhance our data pipelines and systems</li><li>Collaborate with data team and stakeholders including data architects, Executive and Product from the beginning to the delivery of a project </li><li>Ensure the highest quality of data is made available throughout the entire organisation and systems meeting our SLAs</li></ul><p><br></p><p><strong>OUR SUCCESSFUL CANDIDATE WILL HAVE:</strong></p><p><br></p><p>ESSENTIAL SKILLS:</p><ul><li>Experience working in an online, gaming, or fast-moving industry </li><li>3+ years of work experience in data engineers and data platforms</li><li>Must have experience in successfully implementing data-centric applications, such as data warehouses, operational data stores, and data integration projects  </li><li>Experience with SQL, ETL, data modelling, and Python</li><li>Proven experience with Bigquery</li><li>Proficient with one or more big data &amp; new data technologies such as DBT, Apache NiFi, Airflow, Kafka </li><li> </li></ul><p>NICE TO HAVES:</p><ul><li>Experience from the iGaming industry is meriting</li></ul><p><br></p><p><br></p><p><strong>WHO WE ARE</strong></p><p>At the core of LeoVegas Group, is Team Leo. Our culture is our foundation and is what enables us to innovate, build, and lead as we trailblaze our way through the igaming industry. We’re a team of over 1400 innovators, initiators, and groundbreakers working in a fast-paced and agile environment across 11 offices world-wide.</p><p>  </p><p><strong>BENEFITS</strong></p><p><br></p><ul><li>Hybrid work policy</li><li>4 weeks of Workation (T&amp;C apply)</li><li>30 annual vacation days</li><li>Occupational Pension</li><li>5,000 SEK wellness contribution annually</li><li>Parental Leave Top-Up</li><li>Possibility to enrol in a private health care insurance for both you and your partner</li><li>1,500 SEK equipment allowance</li><li>Benify - benefits portal with many offers and discounts</li><li>We offer a relocation package with accommodation and flights.</li></ul><p><br></p><p><strong>JOIN US!</strong></p><p>In our pride, we like to empower our teammates to find their roar and run with their wildest ideas. We don’t wait around for things to happen, we pounce and make it happen!</p><p> </p><p>Would you be a good fit for the Leo Pride - give us a roar!</p><p> </p><p>**As our company working language is English we’d like to see your CV in English please**</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://leovegasgroup.com/careers/open-positions/',
#     'organization_number': '5569396459',
#     'name': 'Gears Of Leo AB',
#     'workplace': 'Gears Of Leo AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://leovegasgroup.com/careers/open-positions/',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'rz2m_96d_vyF',
#     'label': 'Databasutvecklare',
#     'legacy_ams_taxonomy_id': '2423'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Luntmakargatan 18',
#     'postcode': '11137',
#     'city': 'Stockholm',
#     'coordinates': [18.063796539130713, 59.33736093496384]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-10T11:55:35',
#    'last_publication_date': '2024-10-01T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1720605355481},
#   {'relevance': 1.0,
#    'id': '28956784',
#    'external_id': '46-556421-0309-350993987',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28956784',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5564210309/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-08-07T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Det här är vi\n\nFör oss kommer människan alltid först. Och tekniken först därefter. Du ska alltid kunna vara uppkopplad med de och det som betyder mest för just dig. Vår övertygelse är att uppkopplade samhällen är starkare samhällen. Som en Telenor-medarbetare kommer du att vara en viktig pusselbit av en större internationell organisation som vill skapa samhällsnytta genom att leverera förstklassig uppkoppling i de samhällen vi verkar.\n\nTelenor genomgår just nu en digital transformation där vi snabbt strävar efter en helt datastyrd framtid. För att stödja denna satsning investerar vi mycket i området Analytics. Vi letar nu efter en Data Engineer som vill vara en del av denna spännande resa och gå med i vårt Data & Analytics-team.\n\nVad du kommer att göra\n\nDu kommer att vara en del av vårt Data & Analytics team inom Data, Analytics och Automation organisationen. Vi letar nu efter en passionerad Data Engineer som tillsammans med sitt team vill arbeta med att skapa datadrivna beslut och bidra till att driva värde genom data.\n\nI rollen som Data Engineer kommer tillsammans med dina kollegor utveckla lösningar i vår analyticsmiljö och i en agil miljö säkerställa att vi skapar värde för organisationen på bästa möjliga sätt. Du kommer vara en del av olika projekt och samarbeta med kollegor inom såväl det tekniska som affärsnära. Vi tror på samarbete och kontinuerligt lärande. Därför kommer du att få möjlighet att lära dig av dina kollegor och dela med dig av din kunskap med andra, för att tillsammans kunna skapa de bästa möjliga resultaten.\n\nVem du är\n\nFör att lyckas i rollen som Data Engineer har du relevant utbildningsbakgrund och tidigare erfarenhet inom områden som Data Engineer eller liknande roll i Data Lakemiljö.\n\nVi tror också att du har:\n     * Erfaren inom SQL, Python, Java, Qlik Sense/Qlik Cloud, Spark, Airflow, ETL/ELT\n\n     * Erfaren inom cloud services AWS eller GCP\n     * Erfarenhet av statistics\n     * Bakgrund inom telekombranschen är ett stort plus\n     * Flytande i svenska och engelska\n     * Självgående, samarbetsvillig och lösningsorienterad\n\nVårt löfte\n\nNyckeln till vår framgång är en balanserad arbetskraft. För att säkra det arbetar vi aktivt för att främja en arbetsmiljö där våra anställda får stöd och egenmakt inom alla sina arbetsområden. Vi lovar dig ett mänskligt företag som har hög vilja till självförbättring och att snabbt anpassa sig till en digitaliserad värld.\n\nDu välkomnas varmt in till ett skickligt team av professionella kolleger och utöver detta erbjuder vi även:\n\n     * Ett flexibelt arbetssätt. Vi tror på att flexibiliteten och friheten att välja var och när du levererar i ditt arbete bidrar till ökad prestation, engagemang och balans i livet. Vi tror också på styrkan i att vi är bättre tillsammans och att teamandan utvecklas när vi möts och interagerar med varandra, därför ser vi att våra kontor ska agera som magneter för samarbete, kreativitet och företagsanda.\n     * Utbildningsprogram så att du som medarbetare kan fördjupa din kunskap och bredda kompetensen.\n     * Ett generöst hälsovårdspaket innehållandes exempelvis ”give me a break-days”, friskvårdsbidrag, tjänstepension och mycket mer.\n\nSök till oss idag\n\nOm du tycker att det här låter intressant och vill höra mer, vänligen kontakta Marta Jagebro, marta.jagebro@telenor.se. Skicka inte din cv via mail, dessa kommer inte att utvärderas.\n\nSista ansökningsdagen: vi arbetar löpande så sök idag!\n\nPlaceringsort: Stockholm\n\nNote!\n\nUrval och vidare steg kommer genomföras i augusti.\n\nBra att känna till\n\n\xa0Enligt Telenors policy genomför vi bakgrundskontroll på slutkandidat för samtliga rekryteringar.',
#     'text_formatted': 'Det här är vi\n\nFör oss kommer människan alltid först. Och tekniken först därefter. Du ska alltid kunna vara uppkopplad med de och det som betyder mest för just dig. Vår övertygelse är att uppkopplade samhällen är starkare samhällen. Som en Telenor-medarbetare kommer du att vara en viktig pusselbit av en större internationell organisation som vill skapa samhällsnytta genom att leverera förstklassig uppkoppling i de samhällen vi verkar.\n\nTelenor genomgår just nu en digital transformation där vi snabbt strävar efter en helt datastyrd framtid. För att stödja denna satsning investerar vi mycket i området Analytics. Vi letar nu efter en Data Engineer som vill vara en del av denna spännande resa och gå med i vårt Data & Analytics-team.\n\nVad du kommer att göra\n\nDu kommer att vara en del av vårt Data & Analytics team inom Data, Analytics och Automation organisationen. Vi letar nu efter en passionerad Data Engineer som tillsammans med sitt team vill arbeta med att skapa datadrivna beslut och bidra till att driva värde genom data.\n\nI rollen som Data Engineer kommer tillsammans med dina kollegor utveckla lösningar i vår analyticsmiljö och i en agil miljö säkerställa att vi skapar värde för organisationen på bästa möjliga sätt. Du kommer vara en del av olika projekt och samarbeta med kollegor inom såväl det tekniska som affärsnära. Vi tror på samarbete och kontinuerligt lärande. Därför kommer du att få möjlighet att lära dig av dina kollegor och dela med dig av din kunskap med andra, för att tillsammans kunna skapa de bästa möjliga resultaten.\n\nVem du är\n\nFör att lyckas i rollen som Data Engineer har du relevant utbildningsbakgrund och tidigare erfarenhet inom områden som Data Engineer eller liknande roll i Data Lakemiljö.\n\nVi tror också att du har:\n     * Erfaren inom SQL, Python, Java, Qlik Sense/Qlik Cloud, Spark, Airflow, ETL/ELT\n\n     * Erfaren inom cloud services AWS eller GCP\n     * Erfarenhet av statistics\n     * Bakgrund inom telekombranschen är ett stort plus\n     * Flytande i svenska och engelska\n     * Självgående, samarbetsvillig och lösningsorienterad\n\nVårt löfte\n\nNyckeln till vår framgång är en balanserad arbetskraft. För att säkra det arbetar vi aktivt för att främja en arbetsmiljö där våra anställda får stöd och egenmakt inom alla sina arbetsområden. Vi lovar dig ett mänskligt företag som har hög vilja till självförbättring och att snabbt anpassa sig till en digitaliserad värld.\n\nDu välkomnas varmt in till ett skickligt team av professionella kolleger och utöver detta erbjuder vi även:\n\n     * Ett flexibelt arbetssätt. Vi tror på att flexibiliteten och friheten att välja var och när du levererar i ditt arbete bidrar till ökad prestation, engagemang och balans i livet. Vi tror också på styrkan i att vi är bättre tillsammans och att teamandan utvecklas när vi möts och interagerar med varandra, därför ser vi att våra kontor ska agera som magneter för samarbete, kreativitet och företagsanda.\n     * Utbildningsprogram så att du som medarbetare kan fördjupa din kunskap och bredda kompetensen.\n     * Ett generöst hälsovårdspaket innehållandes exempelvis ”give me a break-days”, friskvårdsbidrag, tjänstepension och mycket mer.\n\nSök till oss idag\n\nOm du tycker att det här låter intressant och vill höra mer, vänligen kontakta Marta Jagebro, marta.jagebro@telenor.se. Skicka inte din cv via mail, dessa kommer inte att utvärderas.\n\nSista ansökningsdagen: vi arbetar löpande så sök idag!\n\nPlaceringsort: Stockholm\n\nNote!\n\nUrval och vidare steg kommer genomföras i augusti.\n\nBra att känna till\n\n\xa0Enligt Telenors policy genomför vi bakgrundskontroll på slutkandidat för samtliga rekryteringar.',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'FULLTIME\r\nPERMANENT'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'SALARY',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5564210309',
#     'name': 'Telenor Sverige AB',
#     'workplace': 'Telenor Sverige AB'},
#    'application_details': {'information': None,
#     'reference': 'J123337',
#     'email': None,
#     'via_af': False,
#     'url': 'https://ars2.equest.com/?response_id=8f73d405404af00f809fb6ecabd17608',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'MGBV_LVk_AtK',
#     'label': 'Användbarhetsdesigner',
#     'legacy_ams_taxonomy_id': '6528'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'MGBV_LVk_AtK',
#       'label': 'Användbarhetsdesigner',
#       'legacy_ams_taxonomy_id': '6528'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Recruiter Name',
#      'email': None,
#      'telephone': None,
#      'contact_type': None}],
#    'publication_date': '2024-07-08T15:50:11',
#    'last_publication_date': '2024-08-07T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1720461010245},
#   {'relevance': 1.0,
#    'id': '28952030',
#    'external_id': '46-556016-9095-717',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28952030',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5560169095/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2024-07-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Stockholm Exergi är stockholmarnas energibolag och vi är ca 750 medarbetare som varje dag arbetar för att minska stockholmarnas klimatpåverkan. Vi värmer över 800 000 stockholmare och vårt 300 mil långa fjärrvärmenät är navet för de samhällsnyttor som vi skapar. Vi planerar att bygga en anläggning för koldioxidinfångning vid vårt biokraftvärmeverk i Värtan med potential att fånga in 800 000 ton koldioxid per år, vilket är mer än Stockholms vägtrafik släpper ut under samma period. \nVi behöver fler duktiga medarbetare och hoppas att du vill vara med oss på vår Exergiresa.\n\n\n\xa0Vad kan vi erbjuda dig?\nSom Data Engineer i vårt team hanterar du tillsammans med dina kollegor helheten runt Data & Analytics på Stockholm Exergi. Vi letar efter dig som lockas av idén att jobba med modern teknologi och att skapa bestående värden för våra intressenter. Vi söker dig som vill ha en nyckelroll i att skapa automatiserade arbetsflöden och pipelines för att hämta, organisera och transformera data från olika källor. Som del av teamet inom Data & Analytics skapar du förutsättningar för dataanalytiker och maskininlärningsingenjörer att bygga stabila analyslösningar genom att se till att data finns på rätt plats, i rätt format och i rätt tid, korrekt modellerad och tillgängligt i Power BI.\n\nRollen är en tillsvidareanställning och har sin utgångspunkt i Hjorthagen, Stockholm. Möjlighet till viss distansarbete finns.\n\nVarför jobba med mig?\xa0\nJag tycker om att arbeta på Stockholm Exergi och vill vara med i arbetet mot en hållbar stad. Min prioritet är att det ska kännas schysst att gå till jobbet och att alla får möjlighet att vara den bästa versionen av sig själva. Som person är jag engagerad, transparent och brinner för att få saker gjorda. Jag tror på att arbeta tillsammans, vara prestigelös och se till allas bästa. Tillsammans strävar vi efter att inte bara uppnå höga prestationer utan också att säkerställa ett hållbart arbetsliv för alla.\n\nJag uppskattar att arbeta med personer som är lösningsorienterade, organiserade, kommunikativa och positiva.\n\nAnnika Wallgren, Head of Business Solutions\n\nVem är du som person?\nAlla som jobbar hos oss måste vara nyfikna, ta initiativ och ansvar. För just den här rollen\xa0bör du vara en social person med en positiv inställning. Du kan jobba självständigt men trivs också med att arbete i grupp och har goda presentations- och kommunikationsfärdigheter. Vi ser gärna att du har ett stort leveransfokus och alltid strävar efter hög kvalitet. Vi värdesätter både tekniskt kunnande och god samarbetsförmåga. Ett intresse för att effektivisera och digitalisera verksamheter är något vi uppskattar.\n\n\xa0Krav\n\n• Akademisk utbildning eller motsvarande utbildning i komination med för rollen relevant arbetslivserfarenhet\n• Erfarenhet av arbete som data engineer eller motsvarande\n• Goda kunskaper inom Databricks\n• Goda kunskaper inom Power BI\n• Goda kunskaper inom datamodellering\n• Goda kunskaper inom Python\n• Goda kunskaper inom Microsoft Azure, inkl. Azure Data Factory\n\nNyfiken på oss eller våra anläggningar?\n\n– Det är en blandning av strategiskt och operativt arbete, där jag får tala både med kunder om vad som är bra och vad som kan bli bättre och med utvecklare om hur vi kan lösa det. Det allra roligaste är att få höra av mig tillbaka till kunder som har hjälpt till med feedback i utvecklingen och berätta om att vi har löst det de önskat sig säger Camilla, systemägare\n\nVi är fler kollegor som gärna vill ge en inblick i vårt arbete. Läs våra berättelser här.\n\nTvå av våra anläggningar kan du dessutom besöka virtuellt. Gå in på stockholmexergi.se/virtuell-vartaverket eller stockholmexergi.se/virtuell-bristaverket. Det fungerar i både dator och mobil.\n\n\xa0\n\nRekryteringsprocessen\n\n• Mer nyfiken på hur rekryteringsprocessen går till? Läs mer här.\n\n\nVälkommen med din ansökan senast 31 juli. Urval och intervjuer sker med hänsyn till sommarledighet.',
# ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': '-\r\n-'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Enligt överenskommelse',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5565786414',
#     'name': 'Coromatic AB',
#     'workplace': 'Coromatic AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://career.coromatic.com/jobs/276364-site-engineer-data-center-and-critical-facilities?ref=platsbanken',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': [{'concept_id': 'VTK8_WRx_GcM',
#      'label': 'B',
#      'legacy_ams_taxonomy_id': '3'}],
#    'occupation': {'concept_id': 'Cb5F_v1d_4qK',
#     'label': 'Drifttekniker, data',
#     'legacy_ams_taxonomy_id': '5431'},
#    'occupation_group': {'concept_id': '13md_uyV_BNG',
#     'label': 'Drifttekniker, IT',
#     'legacy_ams_taxonomy_id': '3511'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [18.06858, 59.329323]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'Cb5F_v1d_4qK',
#       'label': 'Drifttekniker, data',
#       'legacy_ams_taxonomy_id': '5431'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-01T10:27:01',
#    'last_publication_date': '2024-08-18T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1719822421470},
#   {'relevance': 0.2507804546311261,
#    'id': '28947663',
#    'external_id': '46-556578-6414-wb-276736',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28947663',
#    'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5565786414/logotyper/logo.png',
#    'headline': 'Site Engineer / Drifttekniker Data Center & Critical Facilities',
#    'application_deadline': '2024-08-15T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vill du vara med och säkra kundens kritiska verksamhet? Vill du dessutom ha ett utvecklande jobb med varierande arbetsuppgifter? Som Site Engineer på Coromatic ligger fokus på förebyggande arbete och riskbedömningar i syfte att säkra kundens dagliga drift.\n\nOm rollen \n\nInom Operations arbetar vi med drift av kunders kritiska verksamheter, primärt datacenter. Våra uppdrag är skräddarsydda efter kundens behov och varierar från deltid till full 24/7/365 närvaro. Som Site Engineer har du ett varierande arbete med fokus främst på förebyggande underhåll, riskbedömningar, metodbeskrivningar och andra aktiviteter som säkrar anläggningens drift. Du ansvarar för flera anläggningar som du ronderar, tolkar värden från och övervakar.\n\nFlera av våra kunder har engelska som dagligt språk i skriftlig kommunikation och arbete inom kritisk verksamhet innebär en hel del administrativa arbetsuppgifter, t.ex. händelserapporter, rotorsaksanalyser, osv – så du behöver vara van vid rapportering och hålla en hög nivå på kvalitet i rapporteringen, både på engelska och svenska.\n\nVi erbjuder en möjlighet att arbeta tillsammans med fantastiska kollegor i ett spännande företag med bra anställningsvillkor och karriärmöjligheter. Hos Coromatic blir du del av ett starkt team med mycket engagemang som ställer upp för varandra 24/7. Att supportera kollegor från andra verksamhetsområden och vara en god arbetskamrat är för oss en självklarhet.\n\nRollen ställer krav på:\n\n• Utbildning/erfarenhet inom något tekniskt område, exempelvis el, ventilation, kyla, automation, brandskydd eller drift \n• Erfarenhet av arbete med larm är meriterande \n• Svenska och engelska, flytande i tal och skrift \n• B-körkort \n\nVem är du? \n\nFör att vara framgångsrik i rollen som Site Engineer behöver du:\n\n• Vara lösningsorienterad och kunna hantera operativ stress när till exempel driftstörning uppstår \n• Noggrann och metodisk i ditt arbete och fungera väl i en processdriven verksamhet \n• God analytisk förmåga \n• Duktig på rapportering och uppföljning av arbete, inklusive rotorsaksanalyser \n• Integritet och att tycka om att ha ansvar \n• Vara duktig på att vårda kundrelationer samt samarbetsförmåga \n• Ödmjuk och lyhörd \n\nOperations är verksamma inom kritiska miljöer som är tekniskt avancerade och ställer högsta krav på säkerhet, noggrannhet, och integritet. På Coromatic står utveckling i fokus – grunden för att vi ska kunna utföra vårt viktiga uppdrag är din kompetens och kompetensutveckling. Därför är ditt intresse och engagemang för ditt område viktigt för att trivas hos oss.\n\nTjänsten innebär resor inom större delen av Skåne och enstaka övernattningar kan bli aktuellt.\n\nAlla roller inom kritisk verksamhet kan vara föremål för utökad säkerhetsprövning, bakgrundskontroll utförs av samtliga medarbetare.\n\nOm Coromatic \n\nCoromatic säkrar tillgång till kraftförsörjning och datakommunikation för verksamhetskritiska anläggningar. Vi tillhandahåller hög tillgänglighet och produktivitet för våra kunder, vi räddar liv genom oavbruten drift 24/7, och optimerar energianvändningen för minsta möjliga miljöpåverkan. När strömmen går ser vi till att Universitetssjukhuset i Linköping alltid har strömförsörjning för fungerande operationssalar och vård. Vi säkrar att Färöborna kan kommunicera med den uppkopplade världen även vid driftsstopp, och att flygplanen alltid kan landa säkert på Bromma flygplats. Coromatic har mer än 700 anställda och har levererat lösningar och tjänster till mer än 5000 företag i Norden. Coromatic är en del av E.ON koncernen. Som Site Engineer hos oss är du med och skapar ett säkrare samhälle. \n\nLåter vi som rätt match för dig? Välkommen in med din ansökan! \n\nVi lägger för denna befattning stor vikt vid personlig lämplighet. \n\nHar du frågor om tjänsten? Kontakta gärna rekryterande chef Thomas Marmin på 0702 - 93 60 70.\n\nTill alla rekryteringssäljare: Tack för att du tänker på och vill hjälpa oss. För att vi alla ...
#     'text_formatted': 'Vill du vara med och säkra kundens kritiska verksamhet? Vill du dessutom ha ett utvecklande jobb med varierande arbetsuppgifter? Som Site Engineer på Coromatic ligger fokus på förebyggande arbete och riskbedömningar i syfte att säkra kundens dagliga drift.\n\nOm rollen \n\nInom Operations arbetar vi med drift av kunders kritiska verksamheter, primärt datacenter. Våra uppdrag är skräddarsydda efter kundens behov och varierar från deltid till full 24/7/365 närvaro. Som Site Engineer har du ett varierande arbete med fokus främst på förebyggande underhåll, riskbedömningar, metodbeskrivningar och andra aktiviteter som säkrar anläggningens drift. Du ansvarar för flera anläggningar som du ronderar, tolkar värden från och övervakar.\n\nFlera av våra kunder har engelska som dagligt språk i skriftlig kommunikation och arbete inom kritisk verksamhet innebär en hel del administrativa arbetsuppgifter, t.ex. händelserapporter, rotorsaksanalyser, osv – så du behöver vara van vid rapportering och hålla en hög nivå på kvalitet i rapporteringen, både på engelska och svenska.\n\nVi erbjuder en möjlighet att arbeta tillsammans med fantastiska kollegor i ett spännande företag med bra anställningsvillkor och karriärmöjligheter. Hos Coromatic blir du del av ett starkt team med mycket engagemang som ställer upp för varandra 24/7. Att supportera kollegor från andra verksamhetsområden och vara en god arbetskamrat är för oss en självklarhet.\n\nRollen ställer krav på:\n\n• Utbildning/erfarenhet inom något tekniskt område, exempelvis el, ventilation, kyla, automation, brandskydd eller drift \n• Erfarenhet av arbete med larm är meriterande \n• Svenska och engelska, flytande i tal och skrift \n• B-körkort \n\nVem är du? \n\nFör att vara framgångsrik i rollen som Site Engineer behöver du:\n\n• Vara lösningsorienterad och kunna hantera operativ stress när till exempel driftstörning uppstår \n• Noggrann och metodisk i ditt arbete och fungera väl i en processdriven verksamhet \n• God analytisk förmåga \n• Duktig på rapportering och uppföljning av arbete, inklusive rotorsaksanalyser \n• Integritet och att tycka om att ha ansvar \n• Vara duktig på att vårda kundrelationer samt samarbetsförmåga \n• Ödmjuk och lyhörd \n\nOperations är verksamma inom kritiska miljöer som är tekniskt avancerade och ställer högsta krav på säkerhet, noggrannhet, och integritet. På Coromatic står utveckling i fokus – grunden för att vi ska kunna utföra vårt viktiga uppdrag är din kompetens och kompetensutveckling. Därför är ditt intresse och engagemang för ditt område viktigt för att trivas hos oss.\n\nTjänsten innebär resor inom större delen av Skåne och enstaka övernattningar kan bli aktuellt.\n\nAlla roller inom kritisk verksamhet kan vara föremål för utökad säkerhetsprövning, bakgrundskontroll utförs av samtliga medarbetare.\n\nOm Coromatic \n\nCoromatic säkrar tillgång till kraftförsörjning och datakommunikation för verksamhetskritiska anläggningar. Vi tillhandahåller hög tillgänglighet och produktivitet för våra kunder, vi räddar liv genom oavbruten drift 24/7, och optimerar energianvändningen för minsta möjliga miljöpåverkan. När strömmen går ser vi till att Universitetssjukhuset i Linköping alltid har strömförsörjning för fungerande operationssalar och vård. Vi säkrar att Färöborna kan kommunicera med den uppkopplade världen även vid driftsstopp, och att flygplanen alltid kan landa säkert på Bromma flygplats. Coromatic har mer än 700 anställda och har levererat lösningar och tjänster till mer än 5000 företag i Norden. Coromatic är en del av E.ON koncernen. Som Site Engineer hos oss är du med och skapar ett säkrare samhälle. \n\nLåter vi som rätt match för dig? Välkommen in med din ansökan! \n\nVi lägger för denna befattning stor vikt vid personlig lämplighet. \n\nHar du frågor om tjänsten? Kontakta gärna rekryterande chef Thomas Marmin på 0702 - 93 60 70.\n\nTill alla rekryteringssäljare: Tack för att du tänker på och vill hjälpa oss. För att vi alla ska  ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': '-\r\n-'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Enligt överenskommelse',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5565786414',
#     'name': 'Coromatic AB',
#     'workplace': 'Coromatic AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://career.coromatic.com/jobs/276736-site-engineer-drifttekniker-data-center-and-critical-facilities?ref=platsbanken',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': [{'concept_id': 'VTK8_WRx_GcM',
#      'label': 'B',
#      'legacy_ams_taxonomy_id': '3'}],
#    'occupation': {'concept_id': 'Cb5F_v1d_4qK',
#     'label': 'Drifttekniker, data',
#     'legacy_ams_taxonomy_id': '5431'},
#    'occupation_group': {'concept_id': '13md_uyV_BNG',
#     'label': 'Drifttekniker, IT',
#     'legacy_ams_taxonomy_id': '3511'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Malmö',
#     'municipality_code': '1280',
#     'municipality_concept_id': 'oYPt_yRA_Smm',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [13.003822, 55.60498]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'Cb5F_v1d_4qK',
#       'label': 'Drifttekniker, data',
#       'legacy_ams_taxonomy_id': '5431'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2024-07-04T15:55:10',
#    'last_publication_date': '2024-08-15T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1720101310606}]}
